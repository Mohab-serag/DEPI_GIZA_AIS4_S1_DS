# %%
is_sunny =True
temp = 25
if is_sunny :
    print("it's sunny day !")
    if temp >20:
        print("the weather is warm")
    else:
        print("the weather is cool")
else:
    print("it's not sunny day .")
# Out:
# it's sunny day !
# the weather is warm

# %%
grade = int(input("enter your grade "))
if 90<= grade <=100:
    print ("A")
elif 80 <= grade <= 90:
    print("B")
elif 70 <= grade <= 80:
    print("C")
elif 60 <= grade <= 70:
    print("D")

# %%
for i in range (6):
     if i == 3:
      continue
     print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
for i in range(6):
    if i ==4:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(5):
    if i ==2:
        pass
    else:
      print(i)
# Out:
# 0
# 1
# 3
# 4
# 5

# %%
x= 6
while x>0:
  print("python")
  x-=1
# Out:
# python
# python
# python
# python
# python
# python

# %%
def info_user(name,age):
   """
   param_1 : take y= the name of user
   type param 1: str
   type param_2 : take the age of the user
   type param_2 : int
   returne : returne string of the name and age 
   type return : str
    """
   return f"my name is {name} and my age is {age}"
   
info_user= info_user("mohab",21)
print(info_user)
# Out:
# my name is mohab and my age is 21

# %%
def func_1 (name , age ):
    print(f"my name is {name} , my age is {age}")
func_1(age =21 ,name="mohab")
# Out:
# my name is mohab , my age is 21

# %%
def func_1 (name , age ):
    print(f"my name is {name} , my age is {age}")
func_1(name ="mohab", age =21)
# Out:
# my name is mohab , my age is 21

# %%
def  function_1(*name):
    print(name)
    print(type(name))
function_1("hello","python","amit" , 2, 2.5,True,["mohab",154,98,"aaaa"])
# Out:
# ('hello', 'python', 'amit', 2, 2.5, True, ['mohab', 154, 98, 'aaaa'])
# <class 'tuple'>

# %%
x=20
"the value of {}".format(x)

# %%
def  function_1(**name):
    print(name)
    print(type(name))
function_1(key ="hello",key_2="python" ,x= 2,y= 2.5,b=True,)
# Out:
# {'key': 'hello', 'key_2': 'python', 'x': 2, 'y': 2.5, 'b': True}
# <class 'dict'>

# %%
result = lambda x: x+10
result(10)
print(type(result))
# Out:
# <class 'function'>

# %%
function_name = lambda x: x+10
function_name(5)
print(function_name)
# Out:
# <function <lambda> at 0x000002369E03EA20>

# %%
function_name = lambda x,y : x+y

print(function_name(5,10))
# Out:
# 15
