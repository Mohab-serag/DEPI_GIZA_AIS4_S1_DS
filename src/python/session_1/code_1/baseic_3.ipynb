# %%
list =[1,2,3,4,"DEPI", "LEARNING",True,[1,2,3,"tRUE",["ML","DL","DS"]]]
print(type(list))
# Out:
# <class 'list'>

# %%
name = "mohab"
print(type(name))
my_list = list(name)      

print(type(my_list))
print(my_list)

my_list[7][4][0] = "DS"

# %%
num =5,6
list (num)

# %%
list_2 =["depi","learning","python"]
list_3 = list_2.append(10)
list_2.insert(0,"Amitt")
print(list_2)
# Out:
# ['Amitt', 'depi', 'learning', 'python', 10]

# %%
list =[1,2,3]
list_2 =[4,5,6]
list.extend(list_2)
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list = ["depi","learning ","learning","python"]
list.remove()
print(list)

# %%
list = ["depi","learning ","learning","python"]
new =list.pop()
print(new)
print(list)
# Out:
# python
# ['depi', 'learning ', 'learning']

# %%
del list [:]
print(list)
# Out:
# []

# %%
name =input()
print(type(name))
# Out:
# <class 'str'>

# %%
name = input("enter name")
id =input("enter id")
print("my name "name,"and my id is "id )
# Out:
# mohab 44

# %%
name = input("enter name")
id =input("enter id")
print(f"my name {name} , and my id is {id}")
# Out:
# my name mohab , and my id is 47952

# %%
# quick quiz
list = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]

item = input("enter the item ")

if item in my_list:
    my_list.remove(item)
print( my_list)
# Out:
# ['learning', 'python', 'machine learning', 'data science', 'deep learning']

# %%
list_new = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]
item = input("enter the item ")
list_new.remove(item)
print(f"output list ={list_new}")
# Out:
# output list =['learning', 'python', 'machine learning', 'data science', 'deep learning']

# %%
my_list =[1,2,2,3]
my_list.index(2)
# Out:
# 1

# %%
my_list =[1,2,2,3]
my_list.count(2)
# Out:
# 2

# %%
my_list_2 =[20,30,48,19,72,50]
my_list_2.sort()
print(my_list_2)
# Out:
# [19, 20, 30, 48, 50, 72]

# %%
my_list_2 =[20,30,48,19,72,50]
my_list_2.reverse()
print(my_list_2)
# Out:
# [50, 72, 19, 48, 30, 20]

# %%
my_list_2 =[20,30,48,19,72,50]
my_list_2.clear()
print(my_list_2)
# Out:
# []

# %%
############################################################################3
###########################TUPLE#############################################

# %%
my_tuple=[20,30,48,19,72,50]
my_tuple.sort()
print(my_tuple)
# Out:
# [19, 20, 30, 48, 50, 72]

# %%
name = "mohab"
tuple(name)
list_1 =list(tuple)
print(list_1)

# %%
color={"red"}
print(type(color))
# Out:
# <class 'set'>

# %%
set_a ={1,2,3}
set_b ={3,4,5}
print(set_a.intersection(set_b))
# Out:
# {3}

# %%
set_a ={1,2,3}
set_b ={3,4,5}
print(set_a.union(set_b))
# Out:
# {1, 2, 3, 4, 5}

# %%
set_a ={1,2,3}
set_b ={3,4,5}
print(set_a.difference(set_b))
# Out:
# {1, 2}

# %%
dict_1 ={"Key1":12,"key2":"python"}
print(type(dict_1))
# Out:
# <class 'dict'>

# %%
dict_1 ={"key1":12,"key2":"python"}
dict_1["key1"] =12.9
dict_1
# Out:
# {'key1': 12.9, 'key2': 'python'}

# %%
key_dict =[("a",1),("b",2),("c",3)]
conv_dict =dict(key_dict)
print(conv_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
num = int(input("enter your number "))
type(num)
# Out:
# int

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
print(f"summation :{num1+num2}")
print(f"subtraction :{num1-num2}")
print(f"multibly :{num1*num2}")
print(f"divition :{num1/num2}")
# Out:
# summation :9.0
# subtraction :1.0
# multibly :20.0
# divition :1.25

# %%
a = 300
b = 33
if b > a:
    print("b is greater than a ")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x =20 
result ="even" if x % 2 ==0 else "odd"
print(result)
# Out:
# even
