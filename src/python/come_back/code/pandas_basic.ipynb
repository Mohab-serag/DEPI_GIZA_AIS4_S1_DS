# %%
import pandas as pd

# %%
s  = pd.Series([1,2,3,4])
type(s)
s1= pd.Series([1,2,3,4], index = ['A','B','C','D'])

# %%
s1
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
data = [[1,444,'abc'],
        [2,555,'def'],
        [3,666,'ghi'],
        [4,444,'xyz']
        ]
data_2 = {'ID':[1,2,3,4],
          'std_id_dict':[444,555,666,444],
          'dept': ['abc','def','ghi', 'xyz']}


df = pd.DataFrame(data, columns=['ID','std_id', 'Dept'])
df
# Out:
#    ID  std_id Dept
# 0   1     444  abc
# 1   2     555  def
# 2   3     666  ghi
# 3   4     444  xyz

# %%
df.columns
# Out:
# Index(['ID', 'std_id', 'Dept'], dtype='object')

# %%
index = ['row1', 'row2', 'row3','row4']
df.index = index 
display(df)
# Out:
#       ID  std_id Dept
# row1   1     444  abc
# row2   2     555  def
# row3   3     666  ghi
# row4   4     444  xyz

# %%
class person:
    def __init__(self, name):
        self.name = name
    @property   
    def getInfo(self):
        return f"my name is {self.name}"

# %%
p1 = person('George')
p1.getInfo
# Out:
# 'my name is George'

# %%
df.dtypes
# Out:
# ID         int64
# std_id     int64
# Dept      object
# dtype: object

# %%
df['Dept'].dtype
# Out:
# dtype('O')

# %%
df['Dept'] = df['Dept'].astype('category')
# df['Dept'].dtype

# %%
df.dtypes
# Out:
# ID           int64
# std_id       int64
# Dept      category
# dtype: object

# %%
df.tail(2)
# Out:
#       ID  std_id Dept
# row3   3     666  ghi
# row4   4     444  xyz

# %%
df.describe(include='category')
# Out:
#        Dept
# count     4
# unique    4
# top     abc
# freq      1

# %%
df.columns
# Out:
# Index(['ID', 'std_id', 'Dept'], dtype='object')

# %%
x = df['std_id'].unique().sum()
x
# Out:
# np.int64(1665)

# %%
df['std_id'].min()
# Out:
# np.int64(444)

# %%
df.Dept.idxmin()
# Out:
# 'row1'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, row1 to row4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      4 non-null      int64
#  1   std_id  4 non-null      int64
#  2   Dept    4 non-null      category
# dtypes: category(1), int64(2)
# memory usage: 304.0+ bytes

# %%
df['ID'].sum()
# Out:
# np.int64(10)

# %%
def duplicate(x):
    return x *2


df['std_id'].apply(lambda x : x*2)
# Out:
# row1     888
# row2    1110
# row3    1332
# row4     888
# Name: std_id, dtype: int64

# %%
df.iloc[2,1]
# Out:
# np.int64(666)

# %%
df.Dept.iloc[0:2]
# Out:
# row1    abc
# row2    def
# Name: Dept, dtype: category
# Categories (4, object): ['abc', 'def', 'ghi', 'xyz']

# %%
num_col = df.iloc[:, :-1]
target_y  = df.iloc[:,-1:]
num_col
# Out:
#       ID  std_id
# row1   1     444
# row2   2     555
# row3   3     666
# row4   4     444

# %%
df['new_col'] = df['std_id'] + df.ID
df
# Out:
#       ID  std_id Dept  new_col
# row1   1     444  abc      445
# row2   2     555  def      557
# row3   3     666  ghi      669
# row4   4     444  xyz      448

# %%
import numpy as np

# %%
data = [[1,444,'abc'],
        [2,555,'def'],
        [3,666,'ghi'],
        [4,np.NAN,'xyz']
        ]

df = pd.DataFrame(data, columns=['ID','std_id', 'Dept'])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 4
#       1 data = [[1,444,'abc'],
#       2         [2,555,'def'],
#       3         [3,666,'ghi'],
# ----> 4         [4,np.NAN,'xyz']
#       5         ]
#       7 df = pd.DataFrame(data, columns=['ID','std_id', 'Dept'])
#       8 df
#
# File c:\python folder\Lib\site-packages\numpy\__init__.py:805, in __getattr__(attr)
#     802     import numpy.char as char
#     803     return char.chararray
# --> 805 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'NAN'

# %%
def isNull(df):
    null = df.isnull().sum()
    return pd.DataFrame(null).T

# %%
null = df.isnull().sum()
pd.DataFrame(null).T
# Out:
#    ID  std_id  Dept
# 0   0       1     0

# %%
from isnullval import  isNull
isNull(df)
# Out:
#    ID  std_id  Dept
# 0   0       1     0

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(["PassengerId", "Name", "Ticket"],axis= 1 ,inplace=True)

# %%
df.head()
# Out:
#       ID  std_id Dept  new_col
# row1   1     444  abc      445
# row2   2     555  def      557
# row3   3     666  ghi      669
# row4   4     444  xyz      448

# %%
dtypes = df.dtypes
n_unique = df.nunique()
pd.DataFrame({"Dtype":dtypes, "num_unique":n_unique}).T
# Out:
#                ID std_id      Dept new_col
# Dtype       int64  int64  category   int64
# num_unique      4      3         4       4

# %%
from preprocessing.chk_t import chk_type
chk_type(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 from preprocessing.chk_t import chk_type
#       2 chk_type(df)
#
# ModuleNotFoundError: No module named 'preprocessing'

# %%
cols = ['Survived','Pclass','Sex','SibSp','Parch','Embarked']
df[cols] = df[cols].astype('category')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 2
#       1 cols = ['Survived','Pclass','Sex','SibSp','Parch','Embarked']
# ----> 2 df[cols] = df[cols].astype('category')
#
# File c:\python folder\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\python folder\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\python folder\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'], dtype='object')] are in the [columns]"

# %%
def handle_types(cols):
    df[cols] = df[cols].astype('category')
    chk_type(df)

# %%
from preprocessing.chk_t import chk_type
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 from preprocessing.chk_t import chk_type
#
# ModuleNotFoundError: No module named 'preprocessing'

# %%
df.shape[0]
# Out:
# 4

# %%
null  =df.isnull().sum()
ratio = null /df.shape[0]
pd.DataFrame({"Null":null, "Ratio":ratio}).T
# Out:
#         ID  std_id  Dept  new_col
# Null   0.0     0.0   0.0      0.0
# Ratio  0.0     0.0   0.0      0.0

# %%
df = df.dropna(subset=['Embarked'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22780\2698502203.py in ?()
# ----> 1 df = df.dropna(subset=['Embarked'])
#
# c:\python folder\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['Embarked']

# %%
df = df.drop('Cabin', axis= 1 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 df = df.drop('Cabin', axis= 1 )
#
# File c:\python folder\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\python folder\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\python folder\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\python folder\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Cabin'] not found in axis"

# %%
median = df['Age'].median()
df['Age'].fillna(median, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\python folder\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 median = df['Age'].median()
#       2 df['Age'].fillna(median, inplace= True)
#
# File c:\python folder\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\python folder\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Age'

# %%
null  =df.isnull().sum()
ratio = null /df.shape[0]
pd.DataFrame({"Null":null, "Ratio":ratio}).T
# Out:
#         ID  std_id  Dept  new_col
# Null   0.0     0.0   0.0      0.0
# Ratio  0.0     0.0   0.0      0.0

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df.dtypes
# Out:
# ID            int64
# std_id        int64
# Dept       category
# new_col       int64
# dtype: object

# %%
num_cols = ['Age','Fare']

# %%
num_cols = df.select_dtypes('number').columns

plt.figure(figsize=(8,4))

for i, col in enumerate(num_cols):
    plt.subplot(len(num_cols), 1, i+1)
    sns.boxplot(x=df[col], orient='h')
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3- Q1
    Lower_Fence = Q1 - 1.5*IQR
    Upper_Fence = Q3 + 1.5*IQR
    Lower_Outliers = df[df[col] < Lower_Fence][col].values
    Upper_Outliers = df[df[col] > Upper_Fence][col].values
    
    df[col].replace(Lower_Outliers, Lower_Fence, inplace=True)
    df[col].replace(Upper_Outliers, Upper_Fence, inplace=True)
# Out:
# C:\Users\mohab\AppData\Local\Temp\ipykernel_22780\2881739099.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace(Lower_Outliers, Lower_Fence, inplace=True)
# C:\Users\mohab\AppData\Local\Temp\ipykernel_22780\2881739099.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace(Upper_Outliers, Upper_Fence, inplace=True)
# C:\Users\mohab\AppData\Local\Temp\ipykernel_22780\2881739099.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace(Lower_Outliers, Lower_Fence, inplace=True)
# C:\Users\mohab\AppData\Local\Temp\ipykernel_22780\2881739099.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace(Upper_Outliers, Upper_Fence, inplace=True)
# C:\Users\mohab\AppData\Local\Temp\ipykernel_22780\2881739099.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace(Lower_Outliers, Lower_Fence, inplace=True)
# C:\Users\mohab\AppData\Local\Temp\ipykernel_22780\2881739099.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace(Upper_Outliers, Upper_Fence, inplace=True)

# %%
num_cols = df.select_dtypes('number').columns

plt.figure(figsize=(8, 4*len(num_cols)))

for i, col in enumerate(num_cols):
    plt.subplot(len(num_cols), 1, i+1)
    sns.boxplot(x=df[col], orient='h')
    plt.title(f"{col} boxplot")

plt.tight_layout()
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,2))

for i, col in enumerate(num_cols):
    plt.subplot(1,2, i+1)
    plt.hist(df[col], edgecolor='black')
    plt.title(f"{col} Distribution Graph")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(9,2))
# ----> 5 for i, col in enumerate(num_cols):
#       6     plt.subplot(1,2, i+1)
#       7     plt.hist(df[col], edgecolor='black')
#
# NameError: name 'num_cols' is not defined

# %%
cats_cols= df.select_dtypes('category').columns
plt.figure(figsize=(14,4))
for i , col in enumerate(cats_cols):
    plt.subplot(2,3 , i+1)
    sns.countplot(x=col ,data =df)
    plt.title(f"{col}Distribution Graph")
plt.subplots_adjust(hspace=0.8 ,wspace=0.3)
plt.show()
