# %%
import random
n= random.random()
def calc_degree(n):
    print(n**n)
    
calc_degree(n)
# Out:
# 0.6986330856660689

# %%
import os
import sys 
base = "C:/Users/Lenovo/Desktop/DEPII/DEPI_GIZA_AIS4_S1_DS/src/python/session_4"

# %%
dir = os.listdir(base)
print(dir)
# Out:
# ['assignment_4', 'code']

# %%
base_dir = "./tmo_directory"
file_name ="text_1.text"
file_path = os.path.join(base_dir,file_name)
file_path
# Out:
# './tmo_directory\\text_1.text'

# %%
import os 
directory = "./tmp_directory_test_again"
if not os.path.exists(directory):
    os.makedirs(directory)
else:
    print("directory already exists",directory)

# %%
import os 
path = "temp_directory"
if not os.path.exists(path):
    os.makedirs(path)
for i in range(20):
    inner_path = os.path.join(path,"dir_"+ str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)
        
        
        
          
        
def  create_folder(path):
  if not os.path.exists(path):
      os.makedirs(path)
  for i in range(20):
      inner_path = os.path.join(path,"dir_"+ str(i))
      if not os.path.exists(inner_path):
        os.makedirs(inner_path)

# %%
create_folder(path)

# %%
with open("temp_directory/text_1.txt", "a+") as file:    
    file.write("new line added\n") 
    file.seek(0)
    update_content =file.read()
    print(update_content)
# Out:
# new line added

# %%
try:
    x= 10
    y=int(input())
    x/y
except:
    print("division by zero")
# Out:
# division by zero

# %%
try:
    5/0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
class StudentInfo:
    def __init__(self, student_name, age, gpa, gender):
        self.student_name = student_name
        self.age = age
        self.gpa = gpa
        self.gender = gender

    def student_info(self):
        return f"Welcome {self.student_name}"

# %%
s1 = StudentInfo("Depi",4,3.99,"male")
s1.student_info()
# Out:
# 'Welcome Depi'

# %%
class test :
    def info(self):
        print(self)

# %%
t1 = test()
print(t1)
print(t1.info())
# Out:
# ...
# None

# %%
class Calc:
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2 
        
    def sum(self):
        return self.num1+self.num2
    def sub(self):
        return self.num1-self.num2

# %%
c1 = Calc(5,3)
c1.sum()
# Out:
# 8

# %%
from abc import ABC,abstractmethod
class Animal(ABC):
    @abstractmethod
    def move(self):
        pass
class Bird(Animal):    
    def move(self):
     print("move from bird")
class Cat(Animal):
    def move(self):
      print("move from Cat")

# %%
a = Bird()
a.move()
# Out:
# move from bird

# %%
a=Animal()
a.move
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 a=Animal()
#       2 a.move
#
# TypeError: Can't instantiate abstract class Animal without an implementation for abstract method 'move'
